# %% [markdown]
# # Tea Drink Visualization
#
# <img src="https://images.unsplash.com/photo-1559056427-6fe5ce77f06d?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=750&q=80" alt="Tea drinking" width="600" />
#
# There are plenty of tea drink products in Indonesia. They are as common as bottled water or coffee these days. Tea drinks can be found on small stores, supermarkets, malls, restaurants, street vendors, and practically everywhere.
#
# Despite its popularity, data analysis about this product is quite rare. Probably due to lack of ready-to-use data. I've found reliable source from Indonesian Food And Drug Administration (Bahasa: BPOM-Badan Pengawas Obat dan Makanan).
#
# Link: http://cekbpom.pom.go.id/index.php/home/produk/r2isesetrjp2lvbjcb4617o7i0/13/row/5100/page/0/order/4/DESC/search/1/minuman%20teh
#
# The data is extracted from html table, converted to CSV, and then cleansed to make it usable for analysis.

# %%
#import libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import itertools
import warnings
warnings.filterwarnings("ignore")
import io
import base64
from matplotlib import rc,animation
from mpl_toolkits.mplot3d import Axes3D
import os
import re

# %%
dataset = pd.read_csv("dataset_bpom_tea.csv")
dataset.head(10)
# Out:
#   nomor_registrasi                                        nama_produk  \
# 0  MD 268313029029                                        Minuman Teh
# 1  MD 268313014046                  Minuman Teh Melati (Original Tea)
# 2  ML 568309009270                     Minuman Teh Hijau Aroma Melati
# 3  MD 268310010072                           Minuman Teh Aroma Melati
# 4  MD 268310004208                        Minuman Teh Putih Rasa Leci
# 5  MD 268311010253                  Minuman Teh Putih Rasa Jeruk Yuzu
# 6  MD 268328002092                      Minuman Teh Hijau Dengan Madu
# 7  MD 268320009024                  Minuman Teh Melati (Original Tea)
# 8  MD 268310012045  Minuman Teh Hijau Rasa Leci (Lychee Green Tea ...
# 9  MD 268310011045  Minuman Teh Hijau Rasa Persik (Peach Green Tea...
#
#         merk  jenis_kemasan                        ukuran_kemasan  \
# 0      Glitz  Gelas Plastik                               (240ml)
# 1  TEH GELAS  Gelas Plastik                        (270ml; 300ml)
# 2       Yeos         Kaleng                               (300ml)
# 3      Zegar  Gelas Plastik   (165ml; 185ml; 220ml; 270ml; 300ml)
# 4     Fiesta  Botol Plastik                               (450ml)
# 5             Botol Plastik          (350ml; 450ml; 485ml; 500ml)
# 6  ICHI OCHA  Botol Plastik                 (350ml; 450ml; 500ml)
# 7  TEH GELAS  Gelas Plastik                        (270ml; 300ml)
# 8  Futami 17  Botol Plastik                        (350ml; 485ml)
# 9  Futami 17  Botol Plastik                        (350ml; 485ml)
#
#                                produsen          kota_produsen  \
# 0              PT SUMBER TIRTA PAMENANG            Kota Kediri
# 1                     PT CS2 POLA SEHAT         Kab. Tangerang
# 2                      PT YHS INDONESIA     Kota Jakarta Pusat
# 3                          PT TANG MAS              Kota Depok
# 4                  PT. HOKKAN INDONESIA             Kab. Bogor
# 5                PT SAVORIA KREASI RASA             Kab. Kudus
# 6  PT. ANUGERAH INDOFOOD BAROKAH MAKMUR   Kota Jakarta Selatan
# 7                     PT CS2 POLA SEHAT         Kab. Tangerang
# 8            PT FUTAMI FOOD & BEVERAGES     Kota Jakarta Utara
# 9            PT FUTAMI FOOD & BEVERAGES     Kota Jakarta Utara
#
#   provinsi_produsen
# 0        Jawa Timur
# 1            Banten
# 2       DKI Jakarta
# 3        Jawa Barat
# 4        Jawa Barat
# 5       Jawa Tengah
# 6       DKI Jakarta
# 7            Banten
# 8       DKI Jakarta
# 9       DKI Jakarta

# %%
dataset.dtypes
# Out:
# nomor_registrasi     object
# nama_produk          object
# merk                 object
# jenis_kemasan        object
# ukuran_kemasan       object
# produsen             object
# kota_produsen        object
# provinsi_produsen    object
# dtype: object

# %% [markdown]
# ## Distribution of Tea Drink Packages

# %%
dataset_kemasan = dataset["jenis_kemasan"].value_counts().reset_index()
dataset_kemasan = dataset_kemasan[dataset_kemasan["jenis_kemasan"]>=2]
plt.figure(figsize=(10,8))
ax = sns.barplot(y=dataset_kemasan["index"][:15],x = dataset_kemasan["jenis_kemasan"][:15],palette="husl",
                 linewidth=1,edgecolor="k"*15)
plt.xlabel("Number of product")
plt.ylabel("Package Type")
plt.grid(True)
plt.title("Distribution of Tea Drink Packages",color='b')

for i,j in enumerate(dataset_kemasan["jenis_kemasan"][:15].astype(str)):
    ax.text(.7,i,j,fontsize = 9,color="black")
plt.show()

# %% [markdown]
# Most of tea drinks are packaged in plastic bottle ("Botol Plastik") or plastic cup ("Gelas Plastik"). Some other packages available are aluminum can, laminated carton, glass bottle, tetrapak, Aluminum foil pouch, and PET plastic bottle. Some products are packaged in plastic ("Plastik"), which is unclear whether it is bottle or cup. It is probably caused by non-standard data entry process.
#
# From this graph, one can conclude that tea drinks largely contributes to plastic production. According to [this source](https://www.wartaekonomi.co.id/read193618/berebut-manisnya-industri-minuman-teh-dalam-kemasan.html), the industry produces roughly 2 billion liters of tea drink annually. Assuming average tea serving size is 350ml, the industry sends **5.7 billion cups/bottles** to the environment annually.

# %% [markdown]
# ## Distribution of Tea Servings

# %% [markdown]
# Tea serving data can be obtained from "ukuran_kemasan" column. Please note that the column contains many values

# %%
#get all serving sizes using regex search over iterated rows
a=[]
for index,item in dataset["ukuran_kemasan"].iteritems():
    for s in re.findall(r'[0-9]+', item):
        a.append(int(s))
#create new Pandas series and group them by 3 serving size groups
index = ['Small', 'Medium', 'Large']
dataset_servings = pd.DataFrame({'value': a})

bins = pd.IntervalIndex.from_tuples([(0, 200), (200,400), (400, 600), (600, 2000)])
dataset_servings = pd.cut(dataset_servings['value'], bins).value_counts()

ax = dataset_servings.plot.bar()
plt.show()

# %% [markdown]
# Majority of tea drinks are served either in cups (up to 200ml) or small bottles (200ml - 400ml). There are slightly more cup-sized products than small-bottle-sized products in market. Regular bottle products exist, although it is not really popular. Some large quantities serving products also exist in market, but it is significantly less than other products.
#
# This finding indicates that Indonesian people preferred compact-sized tea drinks. Probably it is due to easier mobility, and the serving size is just enough to satisfy the thirst.

# %% [markdown]
# ## Distribution of Flavours

# %% [markdown]
# Tea drink has many combination of flavours. It could be either jasmine tea, black tea, white tea, oolong tea, etc. It can be added with honey or milk as well. Some even have fruity flavours like apple, orange, or blackcurrant. Some tea has flavour combination like honey jasmine tea or fruit black tea. To deal with that requirement technically, new columns are created. These columns will display binary characteristic of tea flavours.

# %%
dataset_flavour = dataset
dataset_flavour["is_jasmine"] = [1 if ('Melati' in x or 'Jasmine' in x) else 0 for x in dataset_flavour['nama_produk']]
dataset_flavour["is_black"] = [1 if ('Hitam' in x or 'Black ' in x) else 0 for x in dataset_flavour['nama_produk']]
dataset_flavour["is_green"] = [1 if ('Hijau' in x or 'Green ' in x) else 0 for x in dataset_flavour['nama_produk']]
dataset_flavour["is_white"] = [1 if ('Putih' in x or 'White ' in x) else 0 for x in dataset_flavour['nama_produk']]
dataset_flavour["is_honey"] = [1 i
                              + f ('Madu' in x or 'Honey ' in x) else 0 for x in dataset_flavour['nama_produk']]
dataset_flavour["is_milk"] = [1 if ('Susu' in x or 'Milk ' in x) else 0 for x in dataset_flavour['nama_produk']]
dataset_flavour["is_flavoured"] = [1 if ('Rasa' in x) else 0 for x in dataset_flavour['nama_produk']]
dataset_flavour["is_oolong"] = [1 if ('Oolong' in x) else 0 for x in dataset_flavour['nama_produk']]
dataset_flavour.head(10)
# Out:
#   nomor_registrasi                                        nama_produk  \
# 0  MD 268313029029                                        Minuman Teh
# 1  MD 268313014046                  Minuman Teh Melati (Original Tea)
# 2  ML 568309009270                     Minuman Teh Hijau Aroma Melati
# 3  MD 268310010072                           Minuman Teh Aroma Melati
# 4  MD 268310004208                        Minuman Teh Putih Rasa Leci
# 5  MD 268311010253                  Minuman Teh Putih Rasa Jeruk Yuzu
# 6  MD 268328002092                      Minuman Teh Hijau Dengan Madu
# 7  MD 268320009024                  Minuman Teh Melati (Original Tea)
# 8  MD 268310012045  Minuman Teh Hijau Rasa Leci (Lychee Green Tea ...
# 9  MD 268310011045  Minuman Teh Hijau Rasa Persik (Peach Green Tea...
#
#         merk  jenis_kemasan                        ukuran_kemasan  \
# 0      Glitz  Gelas Plastik                               (240ml)
# 1  TEH GELAS  Gelas Plastik                        (270ml; 300ml)
# 2       Yeos         Kaleng                               (300ml)
# 3      Zegar  Gelas Plastik   (165ml; 185ml; 220ml; 270ml; 300ml)
# 4     Fiesta  Botol Plastik                               (450ml)
# 5             Botol Plastik          (350ml; 450ml; 485ml; 500ml)
# 6  ICHI OCHA  Botol Plastik                 (350ml; 450ml; 500ml)
# 7  TEH GELAS  Gelas Plastik                        (270ml; 300ml)
# 8  Futami 17  Botol Plastik                        (350ml; 485ml)
# 9  Futami 17  Botol Plastik                        (350ml; 485ml)
#
#                                produsen          kota_produsen  \
# 0              PT SUMBER TIRTA PAMENANG            Kota Kediri
# 1                     PT CS2 POLA SEHAT         Kab. Tangerang
# 2                      PT YHS INDONESIA     Kota Jakarta Pusat
# 3                          PT TANG MAS              Kota Depok
# 4                  PT. HOKKAN INDONESIA             Kab. Bogor
# 5                PT SAVORIA KREASI RASA             Kab. Kudus
# 6  PT. ANUGERAH INDOFOOD BAROKAH MAKMUR   Kota Jakarta Selatan
# 7                     PT CS2 POLA SEHAT         Kab. Tangerang
# 8            PT FUTAMI FOOD & BEVERAGES     Kota Jakarta Utara
# 9            PT FUTAMI FOOD & BEVERAGES     Kota Jakarta Utara
#
#   provinsi_produsen  is_jasmine  is_black  is_green  is_honey  is_flavoured  \
# 0        Jawa Timur           0         0         0         0             0
# 1            Banten           1         0         0         0             0
# 2       DKI Jakarta           1         0         1         0             0
# 3        Jawa Barat           1         0         0         0             0
# 4        Jawa Barat           0         0         0         0             1
# 5       Jawa Tengah           0         0         0         0             1
# 6       DKI Jakarta           0         0         1         1             0
# 7            Banten           1         0         0         0             0
# 8       DKI Jakarta           0         0         1         0             1
# 9       DKI Jakarta           0         0         1         0             1
#
#    is_oolong  is_white  is_milk
# 0          0         0        0
# 1          0         0        0
# 2          0         0        0
# 3          0         0        0
# 4          0         1        0
# 5          0         1        0
# 6          0         0        0
# 7          0         0        0
# 8          0         0        0
# 9          0         0        0

# %% [markdown]
# Now that necessary columns are ready, we can proceed to visualization step.
#
# We will use pie chart to show percentage of tea flavour.

# %%
# Jasmine pie chart
labels = ['Jasmine Tea', 'Non-Jasmine Tea']
sizes = [dataset_flavour[dataset_flavour["is_jasmine"]==1].count()["is_jasmine"],dataset_flavour[dataset_flavour["is_jasmine"]==0].count()["is_jasmine"]]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors =['yellow', 'azure'])
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
ax.set_title('Jasmine Tea Product')

plt.show()

# %%
# Black Tea pie chart
labels = ['Black Tea', 'Non-Black Tea']
sizes = [dataset_flavour[dataset_flavour["is_black"]==1].count()["is_black"],dataset_flavour[dataset_flavour["is_black"]==0].count()["is_black"]]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors =['yellow', 'azure'])
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
ax.set_title('Black Tea Product')

plt.show()

# %%
# Green Tea pie chart
labels = ['Green Tea', 'Non-Green Tea']
sizes = [dataset_flavour[dataset_flavour["is_green"]==1].count()["is_green"],dataset_flavour[dataset_flavour["is_green"]==0].count()["is_green"]]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors =['yellow', 'azure'])
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
ax.set_title('Green Tea Product')

plt.show()

# %%
# White Tea pie chart
labels = ['White Tea', 'Non-White Tea']
sizes = [dataset_flavour[dataset_flavour["is_white"]==1].count()["is_white"],dataset_flavour[dataset_flavour["is_white"]==0].count()["is_white"]]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors =['yellow', 'azure'])
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
ax.set_title('White Tea Product')

plt.show()

# %%
# Oolong Tea pie chart
labels = ['Oolong Tea', 'Non-Oolong Tea']
sizes = [dataset_flavour[dataset_flavour["is_oolong"]==1].count()["is_oolong"],dataset_flavour[dataset_flavour["is_oolong"]==0].count()["is_oolong"]]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors =['yellow', 'azure'])
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
ax.set_title('Oolong Tea Product')

plt.show()

# %%
# Flavoured Tea pie chart
labels = ['Flavoured Tea', 'Non-Flavoured  Tea']
sizes = [dataset_flavour[dataset_flavour["is_flavoured"]==1].count()["is_flavoured"],dataset_flavour[dataset_flavour["is_flavoured"]==0].count()["is_flavoured"]]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors =['xkcd:goldenrod', 'xkcd:baby blue'])
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
ax.set_title('Flavoured Tea Product')

plt.show()

# %% [markdown]
# This graph shows interesting insight. **More than half** of tea drinks in Indonesia are flavoured. Different sensation might be expected from tea drink, whether it is fruity , honey, or milk flavour.

# %%
# Honeyed Tea pie chart
labels = ['Honey Flavour Tea', 'Non Honey Flavour Tea']
sizes = [dataset_flavour[dataset_flavour["is_honey"]==1].count()["is_honey"],dataset_flavour[dataset_flavour["is_honey"]==0].count()["is_honey"]]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors =['xkcd:goldenrod', 'xkcd:baby blue'])
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
ax.set_title('Honey Flavour Tea Product')

plt.show()

# %%
# Milk Tea pie chart
labels = ['Milk Flavour Tea', 'Non Milk Flavour Tea']
sizes = [dataset_flavour[dataset_flavour["is_milk"]==1].count()["is_milk"],dataset_flavour[dataset_flavour["is_milk"]==0].count()["is_milk"]]


fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors =['xkcd:goldenrod', 'xkcd:baby blue'])
ax.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
ax.set_title('Milk Flavour Tea Product')

plt.show()

# %% [markdown]
# ## Import vs Local Brands

# %% [markdown]
# The difference from local and import brands can be identified by its registration number. For this case, only two permits matter.
# First, MD registered product indicates that the local producer has its own brand.
# Then, ML registered product indicates that the producer import goods and then sell it in Indonesia. In short, a product with this label means this is importing brand.

# %%
dataset_brand = dataset
dataset_brand["is_local"] = [1 if ('MD' in x ) else 0 for x in dataset_brand['nomor_registrasi']]
dataset_brand
# Out:
#      nomor_registrasi                                        nama_produk  \
# 0     MD 268313029029                                        Minuman Teh
# 1     MD 268313014046                  Minuman Teh Melati (Original Tea)
# 2     ML 568309009270                     Minuman Teh Hijau Aroma Melati
# 3     MD 268310010072                           Minuman Teh Aroma Melati
# 4     MD 268310004208                        Minuman Teh Putih Rasa Leci
# 5     MD 268311010253                  Minuman Teh Putih Rasa Jeruk Yuzu
# 6     MD 268328002092                      Minuman Teh Hijau Dengan Madu
# 7     MD 268320009024                  Minuman Teh Melati (Original Tea)
# 8     MD 268310012045  Minuman Teh Hijau Rasa Leci (Lychee Green Tea ...
# 9     MD 268310011045  Minuman Teh Hijau Rasa Persik (Peach Green Tea...
# 10    MD 268316001050                          Minuman Teh Dalam Kemasan
# 11    MD 268310248047                          Minuman Teh Rasa Stroberi
# 12    MD 268310029208                        Minuman Teh Hijau (Oi Ocha)
# 13    MD 268331004041                  Minuman Teh Melati (Original tea)
# 14    MD 268310007045                        Minuman Teh Hijau Rasa Madu
# 15    MD 168310006047                      Minuman Teh Rasa Blackcurrant
# 16    MD 268311009509                                       MINUMAN TEH
# 4             Fiesta      Botol Plastik                               (450ml)
# 5                         Botol Plastik          (350ml; 450ml; 485ml; 500ml)
# 6          ICHI OCHA      Botol Plastik                 (350ml; 450ml; 500ml)
# 7          TEH GELAS      Gelas Plastik                        (270ml; 300ml)
# 8          Futami 17      Botol Plastik                        (350ml; 485ml)
# 9          Futami 17      Botol Plastik                        (350ml; 485ml)
# 10               TEE      Gelas Plastik                               (180ml)
# 11             SOSRO      Botol Plastik                        (350ml; 500ml)
# 12           OI OCHA      Botol Plastik                 (300ml; 450ml; 500ml)
# 13         Teh Gelas      Gelas Plastik                        (270ml; 300ml)
# 14         Futami 17      Botol Plastik                               (485ml)
# 15             SOSRO         Botol Kaca                               (235ml)
# 16         Teaandtea      Botol Plastik          (250ml; 330ml; 400ml; 540ml)
# 17             SOSRO      Botol Plastik                        (350ml; 500ml)
# 18             SOSRO      Botol Plastik                        (350ml; 500ml)
# 19             SOSRO      Botol Plastik                        (350ml; 500ml)
# 20             SOSRO      Botol Plastik                        (350ml; 500ml)
# 21         TEH GELAS      Botol Plastik   (250ml; 350ml; 400ml; 425ml; 500ml)
# 22             SOSRO      Botol Plastik                        (350ml; 500ml)
# 23             KIRIN            Plastik                               (500ml)
# 24          Ichitan       Botol Plastik                              (310ml)
# 25               RIO            Plastik                        (190ml; 200ml)
# 26             SOSRO     Karton Laminat         (200ml; 250ml; 330ml; 1000ml)
# 27              Hilo     Karton Laminat                               (200ml)
# 28           MOUNTEA      Gelas Plastik                               (170ml)
# 29           MOUNTEA      Gelas Plastik                               (170ml)
# ...              ...                ...                                   ...
# 1050          MARTEA      Gelas Plastik                               (190ml)
# 1051            WOWO      Gelas Plastik                               (210ml)
# 1052           INACO           Tetrapak                               (200ml)
# 1053           SOSRO            Plastik                               (450ml)
# 1054       TEH GELAS           Tetrapak                               (500ml)
# 1055       TEH GELAS           Tetrapak                                 330ml
# 1056          VFresh         Botol Kaca                               (290ml)
# 1057            Foco             Kaleng                        (350ml; 520ml)
# 1058           SISRI      Gelas Plastik                 (210ml; 220ml; 240ml)
# 1059       TEH GELAS           Tetrapak                        (200ml; 250ml)
# 1060          TEKITA      Gelas Plastik          (180ml; 200ml; 220ml; 240ml)
# 1061          TEKITA      Gelas Plastik                        (190ml; 240ml)
# 1062       Ichi Ocha      Botol Plastik                        (350ml; 500ml)
# 1063           SOSRO           Tetrapak                               (250ml)
# 1064       FRESAICON      Botol Plastik                               (260ml)
# 1065         MOUNTEA      Botol Plastik                               (330ml)
# 1066          TEKITA      Gelas Plastik          (180ml; 200ml; 220ml; 240ml)
# 1067       TEH GELAS           Tetrapak                               (330ml)
# 1068       TEH GELAS      Botol Plastik                        (350ml; 500ml)
# 1069           IDOLA            Plastik                               (165ml)
# 1070       TEH GELAS           Tetrapak                               (200ml)
# 1071         FRESTEA            Plastik                               (500ml)
# 1072         FRESTEA            Plastik                               (500ml)
# 1073          KIYORA  Botol Plastik PET                        (330ml; 500ml)
# 1074          TEKITA      Gelas Plastik                        (200ml; 240ml)
# 1062        PT . INDOFOOD ASAHI SUKSES BEVERAGE     Kota Jakarta Pusat
# 1063                             PT.SINAR SOSRO            Kota Bekasi
# 1064              PT.SYNERGY BEVERAGE INDONESIA          Kota Surabaya
# 1065                       PT DHARANA INTI BOGA   Kota Jakarta Selatan
# 1066               PT PRIMA CAHAYA INDOBEVERAGE     Kota Jakarta Pusat
# 1067                          PT CS2 POLA SEHAT         Kab. Tangerang
# 1068                          PT CS2 POLA SEHAT         Kab. Tangerang
# 1069                          PT. PATNA LESTARI            Kab. Subang
# 1070                          PT CS2 POLA SEHAT         Kab. Tangerang
# 1071   PT. COCA-COLA BOTTLING INDONESIACIBITUNG             JAWA BARAT
# 1072   PT. COCA-COLA BOTTLING INDONESIACIBITUNG             JAWA BARAT
# 1073                       PT. HOKKAN INDONESIA             Kab. Bogor
# 1074               PT PRIMA CAHAYA INDOBEVERAGE     Kota Jakarta Pusat
# 1075         PT SINAR SOSRO PABRIK TAMBUNBEKASI             JAWA BARAT
# 1076                          PT CS2 POLA SEHAT         Kab. Tangerang
# 1077                   PT. Indotirta Jaya Abadi          Kota Semarang
# 1078                      PT TIRTA INTI MANDIRI         Kab. Mojokerto
# 1079                   PT. Indotirta Jaya Abadi          Kota Semarang
#
#         provinsi_produsen  is_jasmine  is_black  is_green  is_honey  \
# 0              Jawa Timur           0         0         0         0
# 1                  Banten           1         0         0         0
# 2             DKI Jakarta           1         0         1         0
# 3              Jawa Barat           1         0         0         0
# 4              Jawa Barat           0         0         0         0
# 5             Jawa Tengah           0         0         0         0
# 6             DKI Jakarta           0         0         1         1
# 7                  Banten           1         0         0         0
# 8             DKI Jakarta           0         0         1         0
# 9             DKI Jakarta           0         0         1         0
# 10     Kalimantan Selatan           0         0         0         0
# 11             Jawa Barat           0         0         0         0
# 12             Jawa Barat           0         0         1         0
# 13                 Banten           1         0         0         0
# 14            DKI Jakarta           0         0         1         1
# 15             Jawa Barat           0         0         0         0
# 16            Jawa Tengah           0         0         0         0
# 17             Jawa Barat           0         0         0         0
# 18             Jawa Barat           0         0         0         0
# 19             Jawa Barat           0         0         0         0
# 20             Jawa Barat           0         0         0         0
# 21                 Banten           1         0         0         0
# 22             Jawa Barat           0         0         0         0
# 23            DKI Jakarta           0         0         0         0
# 24             Jawa Barat           0         0         1         0
# 25             Jawa Barat           0         0         0         0
# 26             Jawa Barat           1         0         0         0
# 27            DKI Jakarta           0         0         0         0
# 28                 Banten           0         0         0         0
# 29                 Banten           0         0         0         0
# ...                   ...         ...       ...       ...       ...
# 1050           Jawa Timur           1         0         0         0
# 1051          DKI Jakarta           0         0         0         0
# 1052           Jawa Barat           0         0         1         0
# 1053                  NaN           1         0         0         0
# 1054               Banten           0         0         0         0
# 1055               Banten           0         0         0         0
# 1056          DKI Jakarta           0         0         1         0
# 1057               Banten           0         0         0         0
# 1058               Banten           1         0         0         0
# 1059               Banten           0         0         0         0
# 1060          DKI Jakarta           0         0         1         0
